# %% [markdown]
# 数値評価と可視化

# %%
zeta(2)
# Out:
# 1/6*pi^2

# %%
zeta(I)
# Out:
# zeta(I)

# %%
plot(lambda x: zeta(x), (1.1, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 複素平面での評価とゼロ点探査

# %%
complex_plot(lambda s: abs(zeta(s)), (-20, 20), (-20, 20), plot_points=500)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# 対数積分の計算とプロット
plot(lambda x: li(x) - prime_pi(x), (2, 100))
# Out:
# Graphics object consisting of 1 graphics primitive
